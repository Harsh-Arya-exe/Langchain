# %%
# !pip install langchain chromadb openai tiktoken pypdf langchain_openai langchain-community --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 46.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.2/304.2 kB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 77.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 98.0 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-huggingface langchain-chroma --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 56.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.8 MB/s eta 0:00:00

# %% [markdown]
# # Chromadb

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain.schema import Document
from dotenv import load_dotenv
import os

# %%
embeddings = HuggingFaceEmbeddings(model_name = "sentence-transformers/all-MiniLM-L6-v2")

vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory='chroma_db',
    collection_name='sample'
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# add documents
print(vector_store.add_documents(docs))
# Out:
# ['25a86b43-58a6-4f80-a3e6-c6d8c3c4db35', '9eeb506d-2679-4ceb-b4eb-cb7ad56df4d8', 'a40865f5-3fc4-4e4c-afa0-6360a1341099', 'ba3491da-0b27-47a0-b022-df4b008c2ead', 'adf31d44-6264-43f5-adb8-d62c89130d15']

# %%
#view documents
vector_store.get(include=['embeddings', 'documents', 'metadatas'])
# Out:
# {'ids': ['25a86b43-58a6-4f80-a3e6-c6d8c3c4db35',
#   '9eeb506d-2679-4ceb-b4eb-cb7ad56df4d8',
#   'a40865f5-3fc4-4e4c-afa0-6360a1341099',
#   'ba3491da-0b27-47a0-b022-df4b008c2ead',
#   'adf31d44-6264-43f5-adb8-d62c89130d15'],
#  'embeddings': array([[ 0.00994728,  0.06914341, -0.05147117, ..., -0.03543337,
#           0.0128481 ,  0.01248289],
#         [ 0.00127744,  0.03129853, -0.02375378, ..., -0.00518361,
#          -0.03280616,  0.02737717],
#         [-0.10265916,  0.02650811,  0.02271503, ..., -0.03359746,
#          -0.07984947, -0.01507707],
#         [ 0.02123393, -0.02468548, -0.04494375, ..., -0.10995814,
#           0.00572561,  0.0991538 ],
#         [ 0.01873977,  0.04382848, -0.04304255, ..., -0.0780162 ,
#          -0.07840683, -0.0030419 ]]),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
# ...

# %%
vector_store.similarity_search(
    query='Who among these is a batsman?',
    k=2
)
# Out:
# [Document(id='9eeb506d-2679-4ceb-b4eb-cb7ad56df4d8', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#  Document(id='25a86b43-58a6-4f80-a3e6-c6d8c3c4db35', metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.')]

# %%
#search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these is a batsman?',
    k=2
)
# Out:
# [(Document(id='9eeb506d-2679-4ceb-b4eb-cb7ad56df4d8', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   1.0247342586517334),
#  (Document(id='25a86b43-58a6-4f80-a3e6-c6d8c3c4db35', metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.'),
#   1.045426845550537)]

# %%
#meta-data filtering
vector_store.similarity_search(
    query = '',
    filter = {'team':'Royal Challengers Bangalore'}
)
# Out:
# [Document(id='25a86b43-58a6-4f80-a3e6-c6d8c3c4db35', metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.')]

# %%
#update document
updated_doc1 = Document(
    page_content = "Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata = {'team':'Royal Challengers Bangalore'}
)
vector_store.update_document(
    document_id = '25a86b43-58a6-4f80-a3e6-c6d8c3c4db35',
    document = updated_doc1
)

# %%
vector_store.get(include=['embeddings', 'documents', 'metadatas'])
# Out:
# {'ids': ['25a86b43-58a6-4f80-a3e6-c6d8c3c4db35',
#   '9eeb506d-2679-4ceb-b4eb-cb7ad56df4d8',
#   'a40865f5-3fc4-4e4c-afa0-6360a1341099',
#   'ba3491da-0b27-47a0-b022-df4b008c2ead',
#   'adf31d44-6264-43f5-adb8-d62c89130d15'],
#  'embeddings': array([[-0.00233746,  0.05902082, -0.0477405 , ..., -0.07264049,
#           0.00276782, -0.00344082],
#         [ 0.00127744,  0.03129853, -0.02375378, ..., -0.00518361,
#          -0.03280616,  0.02737717],
#         [-0.10265916,  0.02650811,  0.02271503, ..., -0.03359746,
#          -0.07984947, -0.01507707],
#         [ 0.02123393, -0.02468548, -0.04494375, ..., -0.10995814,
#           0.00572561,  0.0991538 ],
#         [ 0.01873977,  0.04382848, -0.04304255, ..., -0.0780162 ,
#          -0.07840683, -0.0030419 ]]),
# ...

# %%
#delete document
vector_store.delete(
  ids= '9eeb506d-2679-4ceb-b4eb-cb7ad56df4d8'
)
vector_store.get(include=['embeddings', 'documents', 'metadatas'])
# Out:
# {'ids': ['25a86b43-58a6-4f80-a3e6-c6d8c3c4db35',
#   'a40865f5-3fc4-4e4c-afa0-6360a1341099',
#   'ba3491da-0b27-47a0-b022-df4b008c2ead',
#   'adf31d44-6264-43f5-adb8-d62c89130d15'],
#  'embeddings': array([[-0.00233746,  0.05902082, -0.0477405 , ..., -0.07264049,
#           0.00276782, -0.00344082],
#         [-0.10265916,  0.02650811,  0.02271503, ..., -0.03359746,
#          -0.07984947, -0.01507707],
#         [ 0.02123393, -0.02468548, -0.04494375, ..., -0.10995814,
#           0.00572561,  0.0991538 ],
#         [ 0.01873977,  0.04382848, -0.04304255, ..., -0.0780162 ,
#          -0.07840683, -0.0030419 ]]),
# ...

# %% [markdown]
# # Pinecone

# %%
# !pip install langchain-pinecone
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.1/239.1 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -U pinecone-client

# %%
pip install pinecone

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone
from langchain.schema import Document
from dotenv import load_dotenv
import getpass
import os

# %%
embeddings = HuggingFaceEmbeddings(model_name = "sentence-transformers/all-MiniLM-L6-v2")

os.environ['PINECONE_API_KEY'] = getpass.getpass('Enter the pinecone api key')
pc = Pinecone(api_key = os.environ.get('PINECONE_API_KEY'))
index = pc.Index(name = 'langchain-test-index-01')
vector_store = PineconeVectorStore(
    embedding=embeddings,
    index = index
)
# Out:
# Enter the pinecone api key··········

# %%
from langchain.schema import Document

doc1 = Document(
    page_content="Iron Man, also known as Tony Stark, is a genius billionaire and founding member of the Avengers. His armored suits and sharp intellect make him a critical asset in battles.",
    metadata={"team": "Avengers"}
)

doc2 = Document(
    page_content="Captain America, or Steve Rogers, is known for his unwavering moral compass and leadership. Armed with a vibranium shield, he has led the Avengers through major conflicts.",
    metadata={"team": "Avengers"}
)

doc3 = Document(
    page_content="Thor, the God of Thunder from Asgard, wields the powerful hammer Mjölnir and commands lightning. As a core member of the Avengers, his strength and combat skills are unmatched.",
    metadata={"team": "Avengers"}
)

doc4 = Document(
    page_content="Black Widow, also known as Natasha Romanoff, is a skilled spy and fighter. Trained in espionage and martial arts, she plays a vital role in intelligence and combat for the Avengers.",
    metadata={"team": "Avengers"}
)

doc5 = Document(
    page_content="Hulk, the alter ego of Dr. Bruce Banner, transforms into a green powerhouse when angry. His immense strength and resilience make him a formidable force in the Avengers lineup.",
    metadata={"team": "Avengers"}
)

docs = [doc1, doc2, doc3, doc4, doc5]
ids = ['1', '2', '3', '4', '5']

# %%
vector_store.add_documents(documents=docs, ids=ids)
# Out:
# ['1', '2', '3', '4', '5']

# %%
vector_store.similarity_search(
    query = 'Who the smartest avenger',
    k=2
)
# Out:
# [Document(id='1', metadata={'team': 'Avengers'}, page_content='Iron Man, also known as Tony Stark, is a genius billionaire and founding member of the Avengers. His armored suits and sharp intellect make him a critical asset in battles.'),
#  Document(id='3', metadata={'team': 'Avengers'}, page_content='Thor, the God of Thunder from Asgard, wields the powerful hammer Mjölnir and commands lightning. As a core member of the Avengers, his strength and combat skills are unmatched.')]

# %%
vector_store.similarity_search_with_score(
    query='Who among these is strongest?',
    k=2
)
# Out:
# [(Document(id='3', metadata={'team': 'Avengers'}, page_content='Thor, the God of Thunder from Asgard, wields the powerful hammer Mjölnir and commands lightning. As a core member of the Avengers, his strength and combat skills are unmatched.'),
#   0.364916831),
#  (Document(id='5', metadata={'team': 'Avengers'}, page_content='Hulk, the alter ego of Dr. Bruce Banner, transforms into a green powerhouse when angry. His immense strength and resilience make him a formidable force in the Avengers lineup.'),
#   0.302378654)]

# %%
vector_store.delete(ids[2])

# %%
doc_thor_updated = Document(
    page_content=(
        "Thor, the God of Thunder from Asgard, joined the Guardians of the Galaxy after the events of Avengers: Endgame. "
        "Wielding his enchanted axe Stormbreaker, Thor brings immense strength and cosmic power to the team, while adding his unique sense of humor and bravery to their intergalactic adventures."
    ),
    metadata={"team": "Guardians of the Galaxy"}
)

vector_store.add_documents(documents = [doc_thor_updated], ids = [ids[2]])
# Out:
# ['3']

# %%
vector_store.similarity_search(
    query = '',
    k=2,
    filter = {'team':'Guardians of the Galaxy'}
)
# Out:
# [Document(id='3', metadata={'team': 'Guardians of the Galaxy'}, page_content='Thor, the God of Thunder from Asgard, joined the Guardians of the Galaxy after the events of Avengers: Endgame. Wielding his enchanted axe Stormbreaker, Thor brings immense strength and cosmic power to the team, while adding his unique sense of humor and bravery to their intergalactic adventures.')]
